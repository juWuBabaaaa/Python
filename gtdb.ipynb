# %%
import os
import pickle

fp = "/home/wsx/pointcloud_research/data/nuscenes/"
dname = "nuscenes_gt_database"
data = os.listdir(os.path.join(fp, dname))

fname = "nuscenes_dbinfos_train.pkl"
with open(os.path.join(fp, fname), 'rb') as f:
    train_info = pickle.load(f)

# %%
a = {}
a.update(a=1,b=2,c=3)

# %%
a
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
a.values()
# Out:
# dict_values([1, 2, 3])

# %%
a.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
a.items()
# Out:
# dict_items([('a', 1), ('b', 2), ('c', 3)])

# %%
for m, n in a.items():
    print(m)
    print(n)
# Out:
# a
# 1
# b
# 2
# c
# 3

# %%
train_info.keys()
# Out:
# dict_keys(['traffic_cone', 'truck', 'car', 'pedestrian', 'barrier', 'construction_vehicle', 'motorcycle', 'bicycle', 'bus', 'trailer'])

# %%
train_info["car"]
# Out:
# [{'name': 'car',
#   'path': 'nuscenes_gt_database/0_car_3.bin',
#   'image_idx': 0,
#   'gt_idx': 3,
#   'box3d_lidar': array([ 9.21442  , -5.5796075, -1.7985696,  4.25     ,  1.638    ,
#           1.44     ,  0.3584961,  5.52849  ,  1.1955143], dtype=float32),
#   'num_points_in_gt': 1672,
#   'difficulty': 0,
#   'group_id': 3},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/0_car_5.bin',
#   'image_idx': 0,
#   'gt_idx': 5,
#   'box3d_lidar': array([  0.38464648, -13.228449  ,  -1.9426274 ,   4.478     ,
#            1.871     ,   1.456     ,   1.0932099 ,   2.4385812 ,
#            4.212806  ], dtype=float32),
#   'num_points_in_gt': 1661,
#   'difficulty': 0,
#   'group_id': 5},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/1_car_3.bin',
#   'image_idx': 1,
#   'gt_idx': 3,
#   'box3d_lidar': array([10.981341  , -8.903026  , -1.8043277 ,  4.25      ,  1.638     ,
#           1.44      ,  0.02223928,  6.003476  , -0.3397713 ], dtype=float32),
#   'num_points_in_gt': 454,
#   'difficulty': 0,
#   'group_id': 13},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/1_car_5.bin',
#   'image_idx': 1,
#   'gt_idx': 5,
#   'box3d_lidar': array([ -0.23528817, -13.323747  ,  -1.9308441 ,   4.478     ,
#            1.871     ,   1.456     ,   0.88203466,   3.141399  ,
#            3.4238985 ], dtype=float32),
#   'num_points_in_gt': 1536,
#   'difficulty': 0,
#   'group_id': 15},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/2_car_3.bin',
#   'image_idx': 2,
#   'gt_idx': 3,
#   'box3d_lidar': array([ 12.074976  , -13.896959  ,  -1.9091152 ,   4.25      ,
#            1.638     ,   1.44      ,  -0.34347087,   6.020689  ,
#           -2.8549707 ], dtype=float32),
#   'num_points_in_gt': 80,
#   'difficulty': 0,
#   'group_id': 23},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/2_car_5.bin',
#   'image_idx': 2,
#   'gt_idx': 5,
#   'box3d_lidar': array([ -0.9393055, -13.811713 ,  -1.9759843,   4.478    ,   1.871    ,
#            1.456    ,   0.5861377,   3.9555972,   2.0944223], dtype=float32),
#   'num_points_in_gt': 1586,
#   'difficulty': 0,
#   'group_id': 25},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/3_car_3.bin',
#   'image_idx': 3,
#   'gt_idx': 3,
#   'box3d_lidar': array([ 11.861829 , -20.180462 ,  -1.9615862,   4.25     ,   1.638    ,
#            1.44     ,  -0.7043268,   5.226267 ,  -4.786056 ], dtype=float32),
#   'num_points_in_gt': 12,
#   'difficulty': 0,
#   'group_id': 32},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/3_car_5.bin',
#   'image_idx': 3,
#   'gt_idx': 5,
#   'box3d_lidar': array([ -1.3077525 , -14.907557  ,  -1.9624577 ,   4.478     ,
#            1.871     ,   1.456     ,   0.26018834,   4.666042  ,
#            0.49529585], dtype=float32),
#   'num_points_in_gt': 1255,
#   'difficulty': 0,
#   'group_id': 34},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/4_car_2.bin',
#   'image_idx': 4,
#   'gt_idx': 2,
#   'box3d_lidar': array([  9.655532 , -27.277214 ,  -2.17762  ,   4.25     ,   1.638    ,
#            1.44     ,  -1.0082178,   4.1339006,  -6.728862 ], dtype=float32),
#   'num_points_in_gt': 9,
#   'difficulty': 0,
#   'group_id': 42},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/4_car_4.bin',
#   'image_idx': 4,
#   'gt_idx': 4,
#   'box3d_lidar': array([ -1.8761479 , -17.019043  ,  -2.0048106 ,   4.478     ,
#            1.871     ,   1.456     ,  -0.20078228,   5.2020955 ,
#           -1.7843295 ], dtype=float32),
#   'num_points_in_gt': 702,
#   'difficulty': 0,
#   'group_id': 44},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/5_car_4.bin',
#   'image_idx': 5,
#   'gt_idx': 4,
#   'box3d_lidar': array([  5.9443974, -36.143974 ,  -2.3399415,   4.25     ,   1.638    ,
#            1.44     ,  -1.2826002,   2.376188 ,  -8.208464 ], dtype=float32),
#   'num_points_in_gt': 6,
#   'difficulty': 0,
#   'group_id': 55},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/5_car_6.bin',
#   'image_idx': 5,
#   'gt_idx': 6,
#   'box3d_lidar': array([ -2.10059  , -21.175291 ,  -2.0008225,   4.478    ,   1.871    ,
#            1.456    ,  -0.6496976,   4.654116 ,  -4.11061  ], dtype=float32),
#   'num_points_in_gt': 242,
#   'difficulty': 0,
#   'group_id': 57},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/6_car_4.bin',
#   'image_idx': 6,
#   'gt_idx': 4,
#   'box3d_lidar': array([  4.3844557, -43.277645 ,  -2.4056149,   4.25     ,   1.638    ,
#            1.44     ,  -1.3972212,   1.2837878,  -8.545452 ], dtype=float32),
#   'num_points_in_gt': 3,
#   'difficulty': 0,
#   'group_id': 67},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/6_car_6.bin',
#   'image_idx': 6,
#   'gt_idx': 6,
#   'box3d_lidar': array([ -1.4743634, -26.147774 ,  -2.0724208,   4.478    ,   1.871    ,
#            1.456    ,  -0.9213982,   3.5036347,  -5.459097 ], dtype=float32),
#   'num_points_in_gt': 112,
#   'difficulty': 0,
#   'group_id': 69},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/7_car_4.bin',
#   'image_idx': 7,
#   'gt_idx': 4,
#   'box3d_lidar': array([  4.2629757 , -48.960926  ,  -2.3414874 ,   4.25      ,
#            1.638     ,   1.44      ,  -1.4432893 ,   0.67155427,
#           -9.001073  ], dtype=float32),
#   'num_points_in_gt': 2,
#   'difficulty': 0,
#   'group_id': 80},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/7_car_7.bin',
#   'image_idx': 7,
#   'gt_idx': 7,
#   'box3d_lidar': array([ -0.63276833, -30.685856  ,  -2.054416  ,   4.478     ,
#            1.871     ,   1.456     ,  -1.0896393 ,   2.5564644 ,
#           -6.3386564 ], dtype=float32),
#   'num_points_in_gt': 109,
#   'difficulty': 0,
#   'group_id': 83},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/8_car_5.bin',
#   'image_idx': 8,
#   'gt_idx': 5,
#   'box3d_lidar': array([  4.629497  , -56.41629   ,  -2.70473   ,   4.25      ,
#            1.638     ,   1.44      ,  -1.4751757 ,   0.56522906,
#           -9.583355  ], dtype=float32),
#   'num_points_in_gt': 1,
#   'difficulty': 0,
#   'group_id': 94},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/8_car_7.bin',
#   'image_idx': 8,
#   'gt_idx': 7,
#   'box3d_lidar': array([  0.597788 , -36.8415   ,  -2.3017936,   4.478    ,   1.871    ,
#            1.456    ,  -1.2262455,   2.3054934,  -6.931241 ], dtype=float32),
#   'num_points_in_gt': 28,
#   'difficulty': 0,
#   'group_id': 96},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/9_car_3.bin',
#   'image_idx': 9,
#   'gt_idx': 3,
#   'box3d_lidar': array([  4.8850684 , -64.283554  ,  -3.1829283 ,   4.25      ,
#            1.638     ,   1.44      ,  -1.4759482 ,   0.64092356,
#           -9.835292  ], dtype=float32),
#   'num_points_in_gt': 2,
#   'difficulty': 0,
#   'group_id': 105},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/9_car_5.bin',
#   'image_idx': 9,
#   'gt_idx': 5,
#   'box3d_lidar': array([  1.6903268, -43.375385 ,  -2.65278  ,   4.478    ,   1.871    ,
#            1.456    ,  -1.2968313,   1.8431755,  -7.3187895], dtype=float32),
#   'num_points_in_gt': 20,
#   'difficulty': 0,
#   'group_id': 107},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/10_car_5.bin',
#   'image_idx': 10,
#   'gt_idx': 5,
#   'box3d_lidar': array([  2.473672 , -50.064133 ,  -2.8558183,   4.478    ,   1.871    ,
#            1.456    ,  -1.3817799,   1.3569238,  -7.6134925], dtype=float32),
#   'num_points_in_gt': 4,
#   'difficulty': 0,
#   'group_id': 119},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/11_car_6.bin',
#   'image_idx': 11,
#   'gt_idx': 6,
#   'box3d_lidar': array([  3.0439224, -56.871967 ,  -3.4009938,   4.478    ,   1.871    ,
#            1.456    ,  -1.4088383,   1.0424527,  -7.732185 ], dtype=float32),
#   'num_points_in_gt': 0,
#   'difficulty': 0,
#   'group_id': 131},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/12_car_5.bin',
#   'image_idx': 12,
#   'gt_idx': 5,
#   'box3d_lidar': array([  3.4032173 , -63.556335  ,  -3.361513  ,   4.478     ,
#            1.871     ,   1.456     ,  -1.470126  ,   0.90879714,
#           -7.9922075 ], dtype=float32),
#   'num_points_in_gt': 5,
#   'difficulty': 0,
#   'group_id': 143},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/13_car_4.bin',
#   'image_idx': 13,
#   'gt_idx': 4,
#   'box3d_lidar': array([  3.946365  , -70.347534  ,  -3.8137102 ,   4.478     ,
#            1.871     ,   1.456     ,  -1.4518648 ,   0.95559245,
#           -8.316195  ], dtype=float32),
#   'num_points_in_gt': 3,
#   'difficulty': 0,
#   'group_id': 154},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/14_car_4.bin',
#   'image_idx': 14,
#   'gt_idx': 4,
#   'box3d_lidar': array([  4.6015177 , -76.437355  ,  -3.7606733 ,   4.478     ,
#            1.871     ,   1.456     ,  -1.5005534 ,   0.90590054,
#           -8.355113  ], dtype=float32),
#   'num_points_in_gt': 4,
#   'difficulty': 0,
#   'group_id': 165},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/40_car_4.bin',
#   'image_idx': 40,
#   'gt_idx': 4,
#   'box3d_lidar': array([20.569899  , 32.240795  , -0.3044721 ,  4.744     ,  1.802     ,
#           2.        , -1.7325715 , -0.03483315, -1.3863856 ], dtype=float32),
#   'num_points_in_gt': 99,
#   'difficulty': 0,
#   'group_id': 451},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/40_car_15.bin',
#   'image_idx': 40,
#   'gt_idx': 15,
#   'box3d_lidar': array([ 3.7954054 ,  1.6869408 , -1.7684155 ,  4.22      ,  1.902     ,
#           1.477     ,  1.393924  ,  0.63338417,  3.5438986 ], dtype=float32),
#   'num_points_in_gt': 22275,
#   'difficulty': 0,
#   'group_id': 462},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/40_car_21.bin',
#   'image_idx': 40,
#   'gt_idx': 21,
#   'box3d_lidar': array([13.970435  , 32.040535  , -0.22057849,  3.981     ,  1.723     ,
#           1.582     , -1.7615117 ,  0.04689102,  0.10216869], dtype=float32),
#   'num_points_in_gt': 121,
#   'difficulty': 0,
#   'group_id': 468},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/40_car_24.bin',
#   'image_idx': 40,
#   'gt_idx': 24,
#   'box3d_lidar': array([ 1.4030994e+00, -1.3995547e+01, -2.3159254e+00,  5.0929999e+00,
#           2.1370001e+00,  1.6100000e+00,  1.4093179e+00, -1.3572700e-02,
#          -1.5368684e-01], dtype=float32),
#   'num_points_in_gt': 814,
#   'difficulty': 0,
#   'group_id': 471},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/40_car_26.bin',
#   'image_idx': 40,
#   'gt_idx': 26,
#   'box3d_lidar': array([ -3.7625198, -27.025017 ,  -2.9542222,   4.352    ,   1.889    ,
#            1.562    ,   1.4284117,   1.1000499,   7.304167 ], dtype=float32),
#   'num_points_in_gt': 22,
#   'difficulty': 0,
#   'group_id': 473},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/40_car_32.bin',
#   'image_idx': 40,
#   'gt_idx': 32,
#   'box3d_lidar': array([-25.716642  ,  25.98962   ,  -1.2955289 ,   5.078     ,
#            1.954     ,   1.556     ,  -0.16102469,   0.        ,
#            0.        ], dtype=float32),
#   'num_points_in_gt': 11,
#   'difficulty': 0,
#   'group_id': 479},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/40_car_33.bin',
#   'image_idx': 40,
#   'gt_idx': 33,
#   'box3d_lidar': array([-3.1739862e+01,  2.6816490e+01, -1.2796640e+00,  4.5520000e+00,
#           1.9000000e+00,  1.8650000e+00, -1.4357141e-01,  1.9421617e-03,
#           4.7841496e-04], dtype=float32),
#   'num_points_in_gt': 77,
#   'difficulty': 0,
#   'group_id': 480},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/40_car_34.bin',
#   'image_idx': 40,
#   'gt_idx': 34,
#   'box3d_lidar': array([ 3.081374  , -6.1442504 , -1.9953912 ,  5.057     ,  1.954     ,
#           1.934     ,  1.4171718 ,  0.29916245,  2.4606528 ], dtype=float32),
#   'num_points_in_gt': 5742,
#   'difficulty': 0,
#   'group_id': 481},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/40_car_35.bin',
#   'image_idx': 40,
#   'gt_idx': 35,
#   'box3d_lidar': array([-8.8622103e+00,  2.2657879e+01, -1.2297117e+00,  4.6609998e+00,
#           1.8550000e+00,  1.7630000e+00, -1.2014908e-01, -1.7276449e-02,
#           6.1648250e-02], dtype=float32),
#   'num_points_in_gt': 616,
#   'difficulty': 0,
#   'group_id': 482},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/40_car_36.bin',
#   'image_idx': 40,
#   'gt_idx': 36,
#   'box3d_lidar': array([ 2.1750690e+01,  4.0625790e+01, -1.7494071e-01,  4.6090002e+00,
#           1.8140000e+00,  1.5470001e+00, -1.7067232e+00, -2.3804627e-02,
#           3.0512059e-01], dtype=float32),
#   'num_points_in_gt': 44,
#   'difficulty': 0,
#   'group_id': 483},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/41_car_4.bin',
#   'image_idx': 41,
#   'gt_idx': 4,
#   'box3d_lidar': array([21.849436  , 29.249851  , -0.37550515,  4.744     ,  1.802     ,
#           2.        , -1.774352  , -0.33154944, -2.0725257 ], dtype=float32),
#   'num_points_in_gt': 114,
#   'difficulty': 0,
#   'group_id': 489},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/41_car_15.bin',
#   'image_idx': 41,
#   'gt_idx': 15,
#   'box3d_lidar': array([ 4.245554  ,  1.8730876 , -1.7154412 ,  4.22      ,  1.902     ,
#           1.477     ,  1.3521436 ,  0.86604774,  4.0300884 ], dtype=float32),
#   'num_points_in_gt': 12129,
#   'difficulty': 0,
#   'group_id': 500},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/41_car_21.bin',
#   'image_idx': 41,
#   'gt_idx': 21,
#   'box3d_lidar': array([15.318885  , 30.06737   , -0.25849897,  3.981     ,  1.723     ,
#           1.582     , -1.803292  ,  0.05112136,  0.1001159 ], dtype=float32),
#   'num_points_in_gt': 135,
#   'difficulty': 0,
#   'group_id': 506},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/41_car_24.bin',
#   'image_idx': 41,
#   'gt_idx': 24,
#   'box3d_lidar': array([ 8.0026865e-01, -1.5524218e+01, -2.4646394e+00,  5.0929999e+00,
#           2.1370001e+00,  1.6100000e+00,  1.3675375e+00,  9.2046766e-04,
#          -4.9795061e-02], dtype=float32),
#   'num_points_in_gt': 864,
#   'difficulty': 0,
#   'group_id': 509},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/41_car_26.bin',
#   'image_idx': 41,
#   'gt_idx': 26,
#   'box3d_lidar': array([ -4.195282 , -24.628143 ,  -2.8641539,   4.352    ,   1.889    ,
#            1.562    ,   1.3831407,   1.4045564,   7.250241 ], dtype=float32),
#   'num_points_in_gt': 60,
#   'difficulty': 0,
#   'group_id': 511},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/41_car_32.bin',
#   'image_idx': 41,
#   'gt_idx': 32,
#   'box3d_lidar': array([-24.616259 ,  25.626253 ,  -1.1300161,   5.078    ,   1.954    ,
#            1.556    ,  -0.1853518,   0.       ,   0.       ], dtype=float32),
#   'num_points_in_gt': 49,
#   'difficulty': 0,
#   'group_id': 517},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/41_car_33.bin',
#   'image_idx': 41,
#   'gt_idx': 33,
#   'box3d_lidar': array([-3.0597948e+01,  2.6702684e+01, -1.0803062e+00,  4.5520000e+00,
#           1.9000000e+00,  1.8650000e+00, -1.8535180e-01,  2.1593710e-03,
#          -5.8270828e-04], dtype=float32),
#   'num_points_in_gt': 132,
#   'difficulty': 0,
#   'group_id': 518},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/41_car_34.bin',
#   'image_idx': 41,
#   'gt_idx': 34,
#   'box3d_lidar': array([ 3.0166874, -6.454715 , -2.0076282,  5.057    ,  1.954    ,
#           1.934    ,  1.3509568,  0.4015393,  2.446771 ], dtype=float32),
#   'num_points_in_gt': 6180,
#   'difficulty': 0,
#   'group_id': 519},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/41_car_35.bin',
#   'image_idx': 41,
#   'gt_idx': 35,
#   'box3d_lidar': array([-7.9219251e+00,  2.1626244e+01, -1.1502707e+00,  4.6609998e+00,
#           1.8550000e+00,  1.7630000e+00, -1.6338393e-01, -1.3705665e-02,
#           6.2506221e-02], dtype=float32),
#   'num_points_in_gt': 632,
#   'difficulty': 0,
#   'group_id': 520},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/41_car_36.bin',
#   'image_idx': 41,
#   'gt_idx': 36,
#   'box3d_lidar': array([23.418674  , 38.423203  , -0.19669884,  4.609     ,  1.814     ,
#           1.547     , -1.7485036 , -0.03906617, -0.20477761], dtype=float32),
#   'num_points_in_gt': 19,
#   'difficulty': 0,
#   'group_id': 521},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/42_car_3.bin',
#   'image_idx': 42,
#   'gt_idx': 3,
#   'box3d_lidar': array([23.02099   , 25.13596   , -0.49833363,  4.744     ,  1.802     ,
#           2.        , -1.8280799 , -0.7216816 , -2.9867294 ], dtype=float32),
#   'num_points_in_gt': 170,
#   'difficulty': 0,
#   'group_id': 527},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/42_car_16.bin',
#   'image_idx': 42,
#   'gt_idx': 16,
#   'box3d_lidar': array([ 4.927075 ,  2.3503225, -1.6909034,  4.22     ,  1.902    ,
#           1.477    ,  1.2984155,  1.2764161,  4.8903017], dtype=float32),
#   'num_points_in_gt': 7436,
#   'difficulty': 0,
#   'group_id': 540},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/42_car_22.bin',
#   'image_idx': 42,
#   'gt_idx': 22,
#   'box3d_lidar': array([ 1.6931023e+01,  2.7715609e+01, -3.5564706e-01,  3.9809999e+00,
#           1.7230000e+00,  1.5820000e+00, -1.8570201e+00, -1.3417440e-02,
#           5.6668226e-02], dtype=float32),
#   'num_points_in_gt': 146,
#   'difficulty': 0,
#   'group_id': 546},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/42_car_25.bin',
#   'image_idx': 42,
#   'gt_idx': 25,
#   'box3d_lidar': array([ -0.03278146, -17.055658  ,  -2.481072  ,   5.093     ,
#            2.137     ,   1.61      ,   1.3138094 ,   0.02566508,
#            0.0523076 ], dtype=float32),
#   'num_points_in_gt': 398,
#   'difficulty': 0,
#   'group_id': 549},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/42_car_27.bin',
#   'image_idx': 42,
#   'gt_idx': 27,
#   'box3d_lidar': array([ -4.6271057, -22.325108 ,  -2.701981 ,   4.352    ,   1.889    ,
#            1.562    ,   1.325922 ,   1.7921408,   7.065169 ], dtype=float32),
#   'num_points_in_gt': 124,
#   'difficulty': 0,
#   'group_id': 551},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/42_car_33.bin',
#   'image_idx': 42,
#   'gt_idx': 33,
#   'box3d_lidar': array([-23.213692  ,  25.376339  ,  -1.1906202 ,   5.078     ,
#            1.954     ,   1.556     ,  -0.23907986,   0.        ,
#            0.        ], dtype=float32),
#   'num_points_in_gt': 121,
#   'difficulty': 0,
#   'group_id': 557},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/42_car_34.bin',
#   'image_idx': 42,
#   'gt_idx': 34,
#   'box3d_lidar': array([-2.9127720e+01,  2.6771839e+01, -1.1399862e+00,  4.5520000e+00,
#           1.9000000e+00,  1.8650000e+00, -2.3907986e-01,  2.1261249e-03,
#          -6.9826277e-04], dtype=float32),
#   'num_points_in_gt': 112,
#   'difficulty': 0,
#   'group_id': 558},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/42_car_35.bin',
#   'image_idx': 42,
#   'gt_idx': 35,
#   'box3d_lidar': array([ 2.9215968, -6.932964 , -1.9892159,  5.057    ,  1.954    ,
#           1.934    ,  1.2727941,  0.6587888,  2.8096378], dtype=float32),
#   'num_points_in_gt': 5164,
#   'difficulty': 0,
#   'group_id': 559},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/42_car_36.bin',
#   'image_idx': 42,
#   'gt_idx': 36,
#   'box3d_lidar': array([-6.7630625e+00,  2.0516653e+01, -1.2028991e+00,  4.6609998e+00,
#           1.8550000e+00,  1.7630000e+00, -2.1856642e-01, -1.0333064e-02,
#           6.3188471e-02], dtype=float32),
#   'num_points_in_gt': 644,
#   'difficulty': 0,
#   'group_id': 560},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/42_car_37.bin',
#   'image_idx': 42,
#   'gt_idx': 37,
#   'box3d_lidar': array([25.386917  , 35.21956   , -0.29002333,  4.609     ,  1.814     ,
#           1.547     , -1.8022317 , -0.23604055, -1.2662164 ], dtype=float32),
#   'num_points_in_gt': 22,
#   'difficulty': 0,
#   'group_id': 561},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/43_car_3.bin',
#   'image_idx': 43,
#   'gt_idx': 3,
#   'box3d_lidar': array([24.16374   , 20.335035  , -0.95354885,  4.744     ,  1.802     ,
#           2.        , -1.8938862 , -1.1937683 , -3.469771  ], dtype=float32),
#   'num_points_in_gt': 277,
#   'difficulty': 0,
#   'group_id': 568},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/43_car_15.bin',
#   'image_idx': 43,
#   'gt_idx': 15,
#   'box3d_lidar': array([ 5.922329 ,  2.962963 , -1.6812449,  4.22     ,  1.902    ,
#           1.477    ,  1.2326093,  1.8833638,  5.6158843], dtype=float32),
#   'num_points_in_gt': 4065,
#   'difficulty': 0,
#   'group_id': 580},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/43_car_21.bin',
#   'image_idx': 43,
#   'gt_idx': 21,
#   'box3d_lidar': array([ 1.8682476e+01,  2.4912254e+01, -7.0268750e-01,  3.9809999e+00,
#           1.7230000e+00,  1.5820000e+00, -1.9228264e+00, -8.2092583e-02,
#           2.2460541e-02], dtype=float32),
#   'num_points_in_gt': 150,
#   'difficulty': 0,
#   'group_id': 586},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/43_car_24.bin',
#   'image_idx': 43,
#   'gt_idx': 24,
#   'box3d_lidar': array([ -1.1402502 , -18.646511  ,  -2.4159796 ,   5.093     ,
#            2.137     ,   1.61      ,   1.2480031 ,   0.08192343,
#            0.46402204], dtype=float32),
#   'num_points_in_gt': 333,
#   'difficulty': 0,
#   'group_id': 589},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/43_car_26.bin',
#   'image_idx': 43,
#   'gt_idx': 26,
#   'box3d_lidar': array([ -4.965075 , -20.219702 ,  -2.371173 ,   4.352    ,   1.889    ,
#            1.562    ,   1.256625 ,   2.2620633,   6.790984 ], dtype=float32),
#   'num_points_in_gt': 146,
#   'difficulty': 0,
#   'group_id': 591},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/43_car_31.bin',
#   'image_idx': 43,
#   'gt_idx': 31,
#   'box3d_lidar': array([-21.494852  ,  25.193624  ,  -1.1445074 ,   5.078     ,
#            1.954     ,   1.556     ,  -0.30488613,   0.        ,
#            0.        ], dtype=float32),
#   'num_points_in_gt': 153,
#   'difficulty': 0,
#   'group_id': 596},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/43_car_32.bin',
#   'image_idx': 43,
#   'gt_idx': 32,
#   'box3d_lidar': array([-2.7301445e+01,  2.6974543e+01, -1.0425723e+00,  4.5520000e+00,
#           1.9000000e+00,  1.8650000e+00, -3.0488613e-01,  1.9939395e-03,
#           1.6100936e-04], dtype=float32),
#   'num_points_in_gt': 65,
#   'difficulty': 0,
#   'group_id': 597},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/43_car_33.bin',
#   'image_idx': 43,
#   'gt_idx': 33,
#   'box3d_lidar': array([ 2.958308 , -7.194244 , -1.9561274,  5.057    ,  1.954    ,
#           1.934    ,  1.2000066,  1.2858115,  3.473191 ], dtype=float32),
#   'num_points_in_gt': 3824,
#   'difficulty': 0,
#   'group_id': 598},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/43_car_34.bin',
#   'image_idx': 43,
#   'gt_idx': 34,
#   'box3d_lidar': array([-5.4011011e+00,  1.9298803e+01, -1.2854991e+00,  4.6609998e+00,
#           1.8550000e+00,  1.7630000e+00, -2.8582713e-01, -6.1500878e-03,
#           6.3700825e-02], dtype=float32),
#   'num_points_in_gt': 681,
#   'difficulty': 0,
#   'group_id': 599},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/43_car_35.bin',
#   'image_idx': 43,
#   'gt_idx': 35,
#   'box3d_lidar': array([27.409834  , 30.939955  , -0.80245537,  4.609     ,  1.814     ,
#           1.547     , -1.8680379 , -0.7939092 , -2.6931934 ], dtype=float32),
#   'num_points_in_gt': 26,
#   'difficulty': 0,
#   'group_id': 600},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/44_car_3.bin',
#   'image_idx': 44,
#   'gt_idx': 3,
#   'box3d_lidar': array([24.742136 , 14.986009 , -1.1433595,  4.744    ,  1.802    ,
#           2.       , -1.9683914, -1.9111444, -4.4772277], dtype=float32),
#   'num_points_in_gt': 342,
#   'difficulty': 0,
#   'group_id': 608},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/44_car_14.bin',
#   'image_idx': 44,
#   'gt_idx': 14,
#   'box3d_lidar': array([ 7.373143 ,  3.7693372, -1.62187  ,  4.22     ,  1.902    ,
#           1.477    ,  1.1581042,  2.5963929,  6.059521 ], dtype=float32),
#   'num_points_in_gt': 2137,
#   'difficulty': 0,
#   'group_id': 619},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/44_car_22.bin',
#   'image_idx': 44,
#   'gt_idx': 22,
#   'box3d_lidar': array([20.439531  , 21.788095  , -0.8087864 ,  3.981     ,  1.723     ,
#           1.582     , -1.9973316 , -0.07282426,  0.02588449], dtype=float32),
#   'num_points_in_gt': 227,
#   'difficulty': 0,
#   'group_id': 627},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/44_car_25.bin',
#   'image_idx': 44,
#   'gt_idx': 25,
#   'box3d_lidar': array([ -2.4341176, -19.757977 ,  -2.4393747,   5.093    ,   2.137    ,
#            1.61     ,   1.1822246,   0.6943978,   1.5714538], dtype=float32),
#   'num_points_in_gt': 257,
#   'difficulty': 0,
#   'group_id': 630},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/44_car_27.bin',
#   'image_idx': 44,
#   'gt_idx': 27,
#   'box3d_lidar': array([ -5.0764513, -18.193848 ,  -2.2552443,   4.352    ,   1.889    ,
#            1.562    ,   1.1786292,   2.8036072,   6.787185 ], dtype=float32),
#   'num_points_in_gt': 189,
#   'difficulty': 0,
#   'group_id': 632},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/44_car_32.bin',
#   'image_idx': 44,
#   'gt_idx': 32,
#   'box3d_lidar': array([-19.566956 ,  25.042147 ,  -1.1236644,   5.078    ,   1.954    ,
#            1.556    ,  -0.3793913,   0.       ,   0.       ], dtype=float32),
#   'num_points_in_gt': 163,
#   'difficulty': 0,
#   'group_id': 637},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/44_car_33.bin',
#   'image_idx': 44,
#   'gt_idx': 33,
#   'box3d_lidar': array([-2.5223066e+01,  2.7249952e+01, -1.0005443e+00,  4.5520000e+00,
#           1.9000000e+00,  1.8650000e+00, -3.7939131e-01,  1.8221257e-03,
#          -8.9679990e-04], dtype=float32),
#   'num_points_in_gt': 119,
#   'difficulty': 0,
#   'group_id': 638},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/44_car_34.bin',
#   'image_idx': 44,
#   'gt_idx': 34,
#   'box3d_lidar': array([ 3.3364153, -7.23377  , -1.9536572,  5.057    ,  1.954    ,
#           1.934    ,  1.1447   ,  1.9969109,  3.6678278], dtype=float32),
#   'num_points_in_gt': 3547,
#   'difficulty': 0,
#   'group_id': 639},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/44_car_35.bin',
#   'image_idx': 44,
#   'gt_idx': 35,
#   'box3d_lidar': array([-3.9565480e+00,  1.7998592e+01, -1.3113536e+00,  4.6609998e+00,
#           1.8550000e+00,  1.7630000e+00, -3.6178675e-01, -1.2618648e-03,
#           5.8103569e-02], dtype=float32),
#   'num_points_in_gt': 787,
#   'difficulty': 0,
#   'group_id': 640},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/44_car_36.bin',
#   'image_idx': 44,
#   'gt_idx': 36,
#   'box3d_lidar': array([28.947182 , 25.385239 , -1.006711 ,  4.609    ,  1.814    ,
#           1.547    , -1.9425431, -1.2776206, -3.3510625], dtype=float32),
#   'num_points_in_gt': 43,
#   'difficulty': 0,
#   'group_id': 641},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/45_car_3.bin',
#   'image_idx': 45,
#   'gt_idx': 3,
#   'box3d_lidar': array([24.695555 ,  7.192539 , -1.4614748,  4.744    ,  1.802    ,
#           2.       , -2.0841799, -2.7903662, -5.0617676], dtype=float32),
#   'num_points_in_gt': 254,
#   'difficulty': 0,
#   'group_id': 650},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/45_car_13.bin',
#   'image_idx': 45,
#   'gt_idx': 13,
#   'box3d_lidar': array([ 9.761508 ,  4.5272627, -1.596364 ,  4.22     ,  1.902    ,
#           1.477    ,  1.0423157,  3.5237143,  6.1912136], dtype=float32),
#   'num_points_in_gt': 898,
#   'difficulty': 0,
#   'group_id': 660},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/45_car_20.bin',
#   'image_idx': 45,
#   'gt_idx': 20,
#   'box3d_lidar': array([ 2.2761906e+01,  1.7412930e+01, -1.0117764e+00,  3.9809999e+00,
#           1.7230000e+00,  1.5820000e+00, -2.1131201e+00, -1.3044474e-02,
#          -2.2218036e-03], dtype=float32),
#   'num_points_in_gt': 203,
#   'difficulty': 0,
#   'group_id': 667},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/45_car_23.bin',
#   'image_idx': 45,
#   'gt_idx': 23,
#   'box3d_lidar': array([ -3.9143438, -20.02368  ,  -2.3800092,   5.093    ,   2.137    ,
#            1.61     ,   1.144976 ,   1.5795721,   2.2876115], dtype=float32),
#   'num_points_in_gt': 231,
#   'difficulty': 0,
#   'group_id': 670},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/45_car_25.bin',
#   'image_idx': 45,
#   'gt_idx': 25,
#   'box3d_lidar': array([ -4.996591 , -15.411388 ,  -2.1107125,   4.352    ,   1.889    ,
#            1.562    ,   1.0593501,   3.7976997,   6.7112894], dtype=float32),
#   'num_points_in_gt': 266,
#   'difficulty': 0,
#   'group_id': 672},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/45_car_31.bin',
#   'image_idx': 45,
#   'gt_idx': 31,
#   'box3d_lidar': array([-16.565252  ,  25.242952  ,  -1.0505826 ,   5.078     ,
#            1.954     ,   1.556     ,  -0.49517974,   0.        ,
#            0.        ], dtype=float32),
#   'num_points_in_gt': 180,
#   'difficulty': 0,
#   'group_id': 678},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/45_car_32.bin',
#   'image_idx': 45,
#   'gt_idx': 32,
#   'box3d_lidar': array([-2.1925787e+01,  2.8087429e+01, -8.8744384e-01,  4.5520000e+00,
#           1.9000000e+00,  1.8650000e+00, -4.9517974e-01,  1.7071401e-03,
#          -1.1016103e-03], dtype=float32),
#   'num_points_in_gt': 125,
#   'difficulty': 0,
#   'group_id': 679},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/45_car_33.bin',
#   'image_idx': 45,
#   'gt_idx': 33,
#   'box3d_lidar': array([ 3.9713335 , -7.424129  , -1.969065  ,  5.057     ,  1.954     ,
#           1.934     ,  0.96084374,  2.3639052 ,  2.9919522 ], dtype=float32),
#   'num_points_in_gt': 3067,
#   'difficulty': 0,
#   'group_id': 680},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/45_car_34.bin',
#   'image_idx': 45,
#   'gt_idx': 34,
#   'box3d_lidar': array([-1.8701543e+00,  1.6477139e+01, -1.3382457e+00,  4.6609998e+00,
#           1.8550000e+00,  1.7630000e+00, -4.7902963e-01, -2.5266111e-03,
#           1.8556645e-02], dtype=float32),
#   'num_points_in_gt': 1067,
#   'difficulty': 0,
#   'group_id': 681},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/45_car_35.bin',
#   'image_idx': 45,
#   'gt_idx': 35,
#   'box3d_lidar': array([30.721611 , 18.14437  , -1.3371823,  4.609    ,  1.814    ,
#           1.547    , -2.0583315, -1.7251229, -3.3098524], dtype=float32),
#   'num_points_in_gt': 91,
#   'difficulty': 0,
#   'group_id': 682},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/46_car_3.bin',
#   'image_idx': 46,
#   'gt_idx': 3,
#   'box3d_lidar': array([23.623907  ,  0.19215496, -1.9216334 ,  4.744     ,  1.802     ,
#           2.        , -2.205779  , -3.5576196 , -4.8806343 ], dtype=float32),
#   'num_points_in_gt': 649,
#   'difficulty': 0,
#   'group_id': 690},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/46_car_13.bin',
#   'image_idx': 46,
#   'gt_idx': 13,
#   'box3d_lidar': array([12.495551 ,  4.813014 , -1.7128466,  4.22     ,  1.902    ,
#           1.477    ,  0.9207165,  4.687475 ,  6.358369 ], dtype=float32),
#   'num_points_in_gt': 616,
#   'difficulty': 0,
#   'group_id': 700},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/46_car_18.bin',
#   'image_idx': 46,
#   'gt_idx': 18,
#   'box3d_lidar': array([24.750324  , 12.970219  , -1.4344519 ,  3.981     ,  1.723     ,
#           1.582     , -2.220907  ,  0.04162132, -0.04573698], dtype=float32),
#   'num_points_in_gt': 232,
#   'difficulty': 0,
#   'group_id': 705},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/46_car_20.bin',
#   'image_idx': 46,
#   'gt_idx': 20,
#   'box3d_lidar': array([ -5.216897 , -19.760834 ,  -2.257132 ,   5.093    ,   2.137    ,
#            1.61     ,   1.1106433,   2.1401396,   2.9363174], dtype=float32),
#   'num_points_in_gt': 184,
#   'difficulty': 0,
#   'group_id': 707},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/46_car_22.bin',
#   'image_idx': 46,
#   'gt_idx': 22,
#   'box3d_lidar': array([ -4.4013844 , -13.083038  ,  -1.9646764 ,   4.352     ,
#            1.889     ,   1.562     ,   0.93484205,   4.8165374 ,
#            6.304408  ], dtype=float32),
#   'num_points_in_gt': 631,
#   'difficulty': 0,
#   'group_id': 709},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/46_car_28.bin',
#   'image_idx': 46,
#   'gt_idx': 28,
#   'box3d_lidar': array([-13.35966   ,  25.524315  ,  -0.97713053,   5.078     ,
#            1.954     ,   1.556     ,  -0.6167789 ,   0.        ,
#            0.        ], dtype=float32),
#   'num_points_in_gt': 173,
#   'difficulty': 0,
#   'group_id': 715},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/46_car_29.bin',
#   'image_idx': 46,
#   'gt_idx': 29,
#   'box3d_lidar': array([-1.8330648e+01,  2.8997120e+01, -7.5097632e-01,  4.5520000e+00,
#           1.9000000e+00,  1.8650000e+00, -6.1677891e-01,  1.9468877e-03,
#          -4.5758058e-04], dtype=float32),
#   'num_points_in_gt': 186,
#   'difficulty': 0,
#   'group_id': 716},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/46_car_30.bin',
#   'image_idx': 46,
#   'gt_idx': 30,
#   'box3d_lidar': array([ 4.2939563, -8.274094 , -2.0020638,  5.057    ,  1.954    ,
#           1.934    ,  0.7723403,  2.5327458,  2.1475499], dtype=float32),
#   'num_points_in_gt': 2807,
#   'difficulty': 0,
#   'group_id': 717},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/46_car_31.bin',
#   'image_idx': 46,
#   'gt_idx': 31,
#   'box3d_lidar': array([ 1.5680493e-01,  1.5033725e+01, -1.4271327e+00,  4.6609998e+00,
#           1.8550000e+00,  1.7630000e+00, -6.0208327e-01, -1.2316499e-02,
#          -2.1759843e-02], dtype=float32),
#   'num_points_in_gt': 1179,
#   'difficulty': 0,
#   'group_id': 718},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/47_car_3.bin',
#   'image_idx': 47,
#   'gt_idx': 3,
#   'box3d_lidar': array([21.295301 , -6.902596 , -2.0498219,  4.744    ,  1.802    ,
#           2.       , -2.3516848, -4.171614 , -4.4766526], dtype=float32),
#   'num_points_in_gt': 746,
#   'difficulty': 0,
#   'group_id': 723},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/47_car_15.bin',
#   'image_idx': 47,
#   'gt_idx': 15,
#   'box3d_lidar': array([15.975635 ,  4.382613 , -1.6665826,  4.22     ,  1.902    ,
#           1.477    ,  0.7748107,  5.9112725,  5.96629  ], dtype=float32),
#   'num_points_in_gt': 327,
#   'difficulty': 0,
#   'group_id': 735},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/47_car_21.bin',
#   'image_idx': 47,
#   'gt_idx': 21,
#   'box3d_lidar': array([ -6.7233443, -18.7013   ,  -2.1628327,   5.093    ,   2.137    ,
#            1.61     ,   0.89027  ,   2.7247667,   3.0605307], dtype=float32),
#   'num_points_in_gt': 27,
#   'difficulty': 0,
#   'group_id': 741},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/47_car_23.bin',
#   'image_idx': 47,
#   'gt_idx': 23,
#   'box3d_lidar': array([ -3.4093895, -11.022482 ,  -1.9281058,   4.352    ,   1.889    ,
#            1.562    ,   0.7860273,   5.686706 ,   5.54076  ], dtype=float32),
#   'num_points_in_gt': 892,
#   'difficulty': 0,
#   'group_id': 743},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/47_car_29.bin',
#   'image_idx': 47,
#   'gt_idx': 29,
#   'box3d_lidar': array([-9.499159  , 25.712564  , -1.1225687 ,  5.078     ,  1.954     ,
#           1.556     , -0.76268476,  0.        ,  0.        ], dtype=float32),
#   'num_points_in_gt': 229,
#   'difficulty': 0,
#   'group_id': 749},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/47_car_30.bin',
#   'image_idx': 47,
#   'gt_idx': 30,
#   'box3d_lidar': array([-1.3911585e+01,  2.9872412e+01, -9.1472429e-01,  4.5520000e+00,
#           1.9000000e+00,  1.8650000e+00, -7.6268476e-01,  1.4921294e-03,
#          -1.6667447e-03], dtype=float32),
#   'num_points_in_gt': 167,
#   'difficulty': 0,
#   'group_id': 750},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/47_car_31.bin',
#   'image_idx': 47,
#   'gt_idx': 31,
#   'box3d_lidar': array([ 4.489906  , -9.466491  , -1.9798846 ,  5.057     ,  1.954     ,
#           1.934     ,  0.55953014,  2.9298332 ,  1.5652742 ], dtype=float32),
#   'num_points_in_gt': 2419,
#   'difficulty': 0,
#   'group_id': 751},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/47_car_32.bin',
#   'image_idx': 47,
#   'gt_idx': 32,
#   'box3d_lidar': array([ 2.3409424 , 13.356272  , -1.5106175 ,  4.661     ,  1.855     ,
#           1.763     , -0.74944353, -0.01499017, -0.01881905], dtype=float32),
#   'num_points_in_gt': 1664,
#   'difficulty': 0,
#   'group_id': 752},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/47_car_33.bin',
#   'image_idx': 47,
#   'gt_idx': 33,
#   'box3d_lidar': array([31.431288 ,  3.4084995, -1.9767241,  4.609    ,  1.814    ,
#           1.547    , -2.3258367, -3.2745688, -3.475715 ], dtype=float32),
#   'num_points_in_gt': 102,
#   'difficulty': 0,
#   'group_id': 753},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/48_car_2.bin',
#   'image_idx': 48,
#   'gt_idx': 2,
#   'box3d_lidar': array([ 17.533274 , -13.66345  ,  -2.2190218,   4.744    ,   1.802    ,
#            2.       ,  -2.5118499,  -4.892999 ,  -3.783282 ], dtype=float32),
#   'num_points_in_gt': 839,
#   'difficulty': 0,
#   'group_id': 758},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/48_car_13.bin',
#   'image_idx': 48,
#   'gt_idx': 13,
#   'box3d_lidar': array([19.926542 ,  2.7852077, -1.7383775,  4.22     ,  1.902    ,
#           1.477    ,  0.6320989,  7.199081 ,  5.2482333], dtype=float32),
#   'num_points_in_gt': 161,
#   'difficulty': 0,
#   'group_id': 769},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/48_car_17.bin',
#   'image_idx': 48,
#   'gt_idx': 17,
#   'box3d_lidar': array([ 2.7314844e+01,  1.8738090e+00, -1.6169457e+00,  3.9809999e+00,
#           1.7230000e+00,  1.5820000e+00, -2.4993534e+00,  1.1254409e-02,
#          -2.8202741e-03], dtype=float32),
#   'num_points_in_gt': 30,
#   'difficulty': 0,
#   'group_id': 773},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/48_car_19.bin',
#   'image_idx': 48,
#   'gt_idx': 19,
#   'box3d_lidar': array([ -7.9742107 , -17.671661  ,  -2.0658615 ,   5.093     ,
#            2.137     ,   1.61      ,   0.65563756,   3.7348385 ,
#            2.6037095 ], dtype=float32),
#   'num_points_in_gt': 58,
#   'difficulty': 0,
#   'group_id': 775},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/48_car_21.bin',
#   'image_idx': 48,
#   'gt_idx': 21,
#   'box3d_lidar': array([-1.8680551 , -9.571482  , -1.9091742 ,  4.352     ,  1.889     ,
#           1.562     ,  0.62295336,  6.732271  ,  4.7513514 ], dtype=float32),
#   'num_points_in_gt': 1773,
#   'difficulty': 0,
#   'group_id': 777},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/48_car_26.bin',
#   'image_idx': 48,
#   'gt_idx': 26,
#   'box3d_lidar': array([-5.2668624 , 25.385742  , -1.1648526 ,  5.078     ,  1.954     ,
#           1.556     , -0.92284983,  0.        ,  0.        ], dtype=float32),
#   'num_points_in_gt': 300,
#   'difficulty': 0,
#   'group_id': 782},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/48_car_27.bin',
#   'image_idx': 48,
#   'gt_idx': 27,
#   'box3d_lidar': array([-8.9574451e+00,  3.0194786e+01, -9.4246507e-01,  4.5520000e+00,
#           1.9000000e+00,  1.8650000e+00, -9.2284983e-01,  1.3406171e-03,
#          -2.0917193e-03], dtype=float32),
#   'num_points_in_gt': 137,
#   'difficulty': 0,
#   'group_id': 783},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/48_car_28.bin',
#   'image_idx': 48,
#   'gt_idx': 28,
#   'box3d_lidar': array([  4.5204077 , -11.088364  ,  -2.0073133 ,   5.057     ,
#            1.954     ,   1.934     ,   0.3324608 ,   3.016535  ,
#            0.88155335], dtype=float32),
#   'num_points_in_gt': 1926,
#   'difficulty': 0,
#   'group_id': 784},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/48_car_29.bin',
#   'image_idx': 48,
#   'gt_idx': 29,
#   'box3d_lidar': array([ 4.441864  , 11.292346  , -1.5824497 ,  4.661     ,  1.855     ,
#           1.763     , -0.911063  , -0.02072319, -0.01741246], dtype=float32),
#   'num_points_in_gt': 2059,
#   'difficulty': 0,
#   'group_id': 785},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/48_car_30.bin',
#   'image_idx': 48,
#   'gt_idx': 30,
#   'box3d_lidar': array([29.413122 , -4.8223805, -2.198998 ,  4.609    ,  1.814    ,
#           1.547    , -2.4860017, -4.552286 , -3.5023646], dtype=float32),
#   'num_points_in_gt': 261,
#   'difficulty': 0,
#   'group_id': 786},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/49_car_4.bin',
#   'image_idx': 49,
#   'gt_idx': 4,
#   'box3d_lidar': array([ 13.240294 , -18.577854 ,  -2.2272246,   4.744    ,   1.802    ,
#            2.       ,  -2.6541615,  -5.7186713,  -3.0546808], dtype=float32),
#   'num_points_in_gt': 807,
#   'difficulty': 0,
#   'group_id': 793},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/49_car_14.bin',
#   'image_idx': 49,
#   'gt_idx': 14,
#   'box3d_lidar': array([23.445494  ,  0.27689567, -1.7024878 ,  4.22      ,  1.902     ,
#           1.477     ,  0.5072406 ,  8.459117  ,  4.7608347 ], dtype=float32),
#   'num_points_in_gt': 100,
#   'difficulty': 0,
#   'group_id': 803},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/49_car_18.bin',
#   'image_idx': 49,
#   'gt_idx': 18,
#   'box3d_lidar': array([ 2.7315868e+01, -3.3903089e+00, -1.8642251e+00,  3.9809999e+00,
#           1.7230000e+00,  1.5820000e+00, -2.6503916e+00,  1.6776959e-03,
#           5.8609739e-02], dtype=float32),
#   'num_points_in_gt': 166,
#   'difficulty': 0,
#   'group_id': 807},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/49_car_19.bin',
#   'image_idx': 49,
#   'gt_idx': 19,
#   'box3d_lidar': array([ -8.523832  , -16.913343  ,  -2.0077324 ,   5.093     ,
#            2.137     ,   1.61      ,   0.43885857,   4.2029705 ,
#            1.827228  ], dtype=float32),
#   'num_points_in_gt': 115,
#   'difficulty': 0,
#   'group_id': 808},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/49_car_21.bin',
#   'image_idx': 49,
#   'gt_idx': 21,
#   'box3d_lidar': array([-0.13182433, -9.034181  , -2.0097187 ,  4.352     ,  1.889     ,
#           1.562     ,  0.47773287,  7.8739996 ,  4.0525975 ], dtype=float32),
#   'num_points_in_gt': 3920,
#   'difficulty': 0,
#   'group_id': 810},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/49_car_27.bin',
#   'image_idx': 49,
#   'gt_idx': 27,
#   'box3d_lidar': array([-1.6019131, 24.47349  , -1.1767569,  5.078    ,  1.954    ,
#           1.556    , -1.0651615,  0.       ,  0.       ], dtype=float32),
#   'num_points_in_gt': 432,
#   'difficulty': 0,
#   'group_id': 816},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/49_car_28.bin',
#   'image_idx': 49,
#   'gt_idx': 28,
#   'box3d_lidar': array([-4.5706787e+00,  2.9756130e+01, -9.3296987e-01,  4.5520000e+00,
#           1.9000000e+00,  1.8650000e+00, -1.0651615e+00,  1.0295847e-03,
#          -2.2591327e-03], dtype=float32),
#   'num_points_in_gt': 166,
#   'difficulty': 0,
#   'group_id': 817},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/49_car_29.bin',
#   'image_idx': 49,
#   'gt_idx': 29,
#   'box3d_lidar': array([  4.072526  , -12.875223  ,  -2.0761883 ,   5.057     ,
#            1.954     ,   1.934     ,   0.15815145,   2.5767505 ,
#            0.27926353], dtype=float32),
#   'num_points_in_gt': 1388,
#   'difficulty': 0,
#   'group_id': 818},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/49_car_30.bin',
#   'image_idx': 49,
#   'gt_idx': 30,
#   'box3d_lidar': array([ 5.999096  ,  9.139702  , -1.6416826 ,  4.661     ,  1.855     ,
#           1.763     , -1.0548291 , -0.02280177, -0.01585263], dtype=float32),
#   'num_points_in_gt': 2524,
#   'difficulty': 0,
#   'group_id': 819},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/49_car_31.bin',
#   'image_idx': 49,
#   'gt_idx': 31,
#   'box3d_lidar': array([ 26.320965 , -11.541885 ,  -2.403388 ,   4.609    ,   1.814    ,
#            1.547    ,  -2.6457665,  -5.371598 ,  -2.9537456], dtype=float32),
#   'num_points_in_gt': 262,
#   'difficulty': 0,
#   'group_id': 820},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/50_car_3.bin',
#   'image_idx': 50,
#   'gt_idx': 3,
#   'box3d_lidar': array([  6.210957 , -23.663225 ,  -2.183507 ,   4.744    ,   1.802    ,
#            2.       ,  -2.8293061,  -6.432583 ,  -2.1258507], dtype=float32),
#   'num_points_in_gt': 384,
#   'difficulty': 0,
#   'group_id': 827},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/50_car_13.bin',
#   'image_idx': 50,
#   'gt_idx': 13,
#   'box3d_lidar': array([27.751669 , -4.452711 , -1.8448659,  4.22     ,  1.902    ,
#           1.477    ,  0.3146426,  9.684971 ,  3.2327936], dtype=float32),
#   'num_points_in_gt': 73,
#   'difficulty': 0,
#   'group_id': 837},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/50_car_19.bin',
#   'image_idx': 50,
#   'gt_idx': 19,
#   'box3d_lidar': array([ 2.6143639e+01, -1.0429574e+01, -2.0591350e+00,  3.9809999e+00,
#           1.7230000e+00,  1.5820000e+00, -2.8517163e+00,  1.1573490e-02,
#           5.1460322e-02], dtype=float32),
#   'num_points_in_gt': 307,
#   'difficulty': 0,
#   'group_id': 843},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/50_car_21.bin',
#   'image_idx': 50,
#   'gt_idx': 21,
#   'box3d_lidar': array([ -9.590665  , -16.463373  ,  -1.9315598 ,   5.093     ,
#            2.137     ,   1.61      ,   0.24451528,   3.8457718 ,
#            0.76412183], dtype=float32),
#   'num_points_in_gt': 150,
#   'difficulty': 0,
#   'group_id': 845},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/50_car_23.bin',
#   'image_idx': 50,
#   'gt_idx': 23,
#   'box3d_lidar': array([ 2.464719  , -9.483606  , -1.9513425 ,  4.352     ,  1.889     ,
#           1.562     ,  0.28222603,  8.682527  ,  2.5263534 ], dtype=float32),
#   'num_points_in_gt': 1485,
#   'difficulty': 0,
#   'group_id': 847},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/50_car_29.bin',
#   'image_idx': 50,
#   'gt_idx': 29,
#   'box3d_lidar': array([ 3.08958  , 22.428637 , -1.3738673,  5.078    ,  1.954    ,
#           1.556    , -1.2577595,  0.       ,  0.       ], dtype=float32),
#   'num_points_in_gt': 463,
#   'difficulty': 0,
#   'group_id': 853},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/50_car_30.bin',
#   'image_idx': 50,
#   'gt_idx': 30,
#   'box3d_lidar': array([ 1.1883419e+00,  2.8182375e+01, -1.1508758e+00,  4.5520000e+00,
#           1.9000000e+00,  1.8650000e+00, -1.2577595e+00,  5.1983009e-04,
#          -2.1719597e-03], dtype=float32),
#   'num_points_in_gt': 182,
#   'difficulty': 0,
#   'group_id': 854},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/50_car_31.bin',
#   'image_idx': 50,
#   'gt_idx': 31,
#   'box3d_lidar': array([  2.6704698 , -15.436115  ,  -2.0754433 ,   5.057     ,
#            1.954     ,   1.934     ,  -0.06644421,   2.3147707 ,
#           -0.27154523], dtype=float32),
#   'num_points_in_gt': 440,
#   'difficulty': 0,
#   'group_id': 855},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/50_car_33.bin',
#   'image_idx': 50,
#   'gt_idx': 33,
#   'box3d_lidar': array([ 7.60369   ,  5.9165173 , -1.7680578 ,  4.661     ,  1.855     ,
#           1.763     , -1.2488815 , -0.02285772, -0.01007108], dtype=float32),
#   'num_points_in_gt': 3653,
#   'difficulty': 0,
#   'group_id': 857},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/50_car_34.bin',
#   'image_idx': 50,
#   'gt_idx': 34,
#   'box3d_lidar': array([ 20.65449  , -19.184141 ,  -2.4641623,   4.609    ,   1.814    ,
#            1.547    ,  -2.8209112,  -6.1286063,  -1.9735404], dtype=float32),
#   'num_points_in_gt': 245,
#   'difficulty': 0,
#   'group_id': 858},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/51_car_3.bin',
#   'image_idx': 51,
#   'gt_idx': 3,
#   'box3d_lidar': array([ -1.1813892, -27.005663 ,  -2.1699395,   4.744    ,   1.802    ,
#            2.       ,  -3.0124383,  -7.47609  ,  -1.304221 ], dtype=float32),
#   'num_points_in_gt': 30,
#   'difficulty': 0,
#   'group_id': 866},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/51_car_5.bin',
#   'image_idx': 51,
#   'gt_idx': 5,
#   'box3d_lidar': array([ 28.97103  , -22.773281 ,  -2.7585225,   4.693    ,   1.977    ,
#            1.503    ,  -3.005614 ,  -5.7078886,  -0.5496528], dtype=float32),
#   'num_points_in_gt': 15,
#   'difficulty': 0,
#   'group_id': 868},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/51_car_15.bin',
#   'image_idx': 51,
#   'gt_idx': 15,
#   'box3d_lidar': array([ 31.77573   , -10.2871685 ,  -2.323351  ,   4.22      ,
#            1.902     ,   1.477     ,   0.14896394,  10.390923  ,
#            1.4651219 ], dtype=float32),
#   'num_points_in_gt': 29,
#   'difficulty': 0,
#   'group_id': 878},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/51_car_22.bin',
#   'image_idx': 51,
#   'gt_idx': 22,
#   'box3d_lidar': array([ 2.4038363e+01, -1.6621019e+01, -2.4397502e+00,  3.9809999e+00,
#           1.7230000e+00,  1.5820000e+00, -3.0261216e+00,  1.9888170e-02,
#           4.8826747e-02], dtype=float32),
#   'num_points_in_gt': 228,
#   'difficulty': 0,
#   'group_id': 885},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/51_car_24.bin',
#   'image_idx': 51,
#   'gt_idx': 24,
#   'box3d_lidar': array([-1.0358967e+01, -1.6663046e+01, -1.8605165e+00,  5.0929999e+00,
#           2.1370001e+00,  1.6100000e+00,  7.7091284e-02,  3.2091970e+00,
#          -1.1834617e-02], dtype=float32),
#   'num_points_in_gt': 228,
#   'difficulty': 0,
#   'group_id': 887},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/51_car_26.bin',
#   'image_idx': 51,
#   'gt_idx': 26,
#   'box3d_lidar': array([  5.3275285 , -11.285292  ,  -2.0117927 ,   4.352     ,
#            1.889     ,   1.562     ,   0.11363848,   9.060831  ,
#            1.0843489 ], dtype=float32),
#   'num_points_in_gt': 876,
#   'difficulty': 0,
#   'group_id': 889},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/51_car_31.bin',
#   'image_idx': 51,
#   'gt_idx': 31,
#   'box3d_lidar': array([ 6.709309 , 19.559376 , -1.5255294,  5.078    ,  1.954    ,
#           1.556    , -1.4234381,  0.       ,  0.       ], dtype=float32),
#   'num_points_in_gt': 458,
#   'difficulty': 0,
#   'group_id': 894},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/51_car_32.bin',
#   'image_idx': 51,
#   'gt_idx': 32,
#   'box3d_lidar': array([ 5.7864666e+00,  2.5547094e+01, -1.2965696e+00,  4.5520000e+00,
# ...
#            4.8113365 ], dtype=float32),
#   'num_points_in_gt': 10,
#   'difficulty': 0,
#   'group_id': 9419},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/376_car_14.bin',
#   'image_idx': 376,
#   'gt_idx': 14,
#   'box3d_lidar': array([ -2.52793   , -69.34361   ,  -3.2210686 ,   3.899     ,
#            1.968     ,   1.673     ,   1.689285  ,  -0.24569398,
#            1.2200334 ], dtype=float32),
#   'num_points_in_gt': 21,
#   'difficulty': 0,
#   'group_id': 9424},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/376_car_16.bin',
#   'image_idx': 376,
#   'gt_idx': 16,
#   'box3d_lidar': array([-3.8628676 , 50.18932   , -1.2235328 ,  4.461     ,  1.787     ,
#           1.534     ,  1.7134142 , -0.25801647,  1.2455384 ], dtype=float32),
#   'num_points_in_gt': 12,
#   'difficulty': 0,
#   'group_id': 9426},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/377_car_7.bin',
#   'image_idx': 377,
#   'gt_idx': 7,
#   'box3d_lidar': array([-1.394566  , 35.956818  , -0.96916   ,  4.429     ,  1.853     ,
#           1.477     ,  1.6195123 , -0.04791513,  2.2338533 ], dtype=float32),
#   'num_points_in_gt': 16,
#   'difficulty': 0,
#   'group_id': 9437},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/377_car_10.bin',
#   'image_idx': 377,
#   'gt_idx': 10,
#   'box3d_lidar': array([ -0.27400023, -71.89364   ,  -3.5128512 ,   4.27      ,
#            2.218     ,   1.867     ,   1.6371053 ,  -0.30809814,
#            4.583636  ], dtype=float32),
#   'num_points_in_gt': 0,
#   'difficulty': 0,
#   'group_id': 9440},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/377_car_15.bin',
#   'image_idx': 377,
#   'gt_idx': 15,
#   'box3d_lidar': array([ -3.0816164, -71.40762  ,  -3.3896632,   3.899    ,   1.968    ,
#            1.673    ,   1.6813756,  -0.2464475,   1.7457852], dtype=float32),
#   'num_points_in_gt': 1,
#   'difficulty': 0,
#   'group_id': 9445},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/377_car_17.bin',
#   'image_idx': 377,
#   'gt_idx': 17,
#   'box3d_lidar': array([-3.7100804 , 47.908924  , -1.1585617 ,  4.461     ,  1.787     ,
#           1.534     ,  1.6945964 , -0.17728364,  0.7260415 ], dtype=float32),
#   'num_points_in_gt': 30,
#   'difficulty': 0,
#   'group_id': 9447},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/378_car_7.bin',
#   'image_idx': 378,
#   'gt_idx': 7,
#   'box3d_lidar': array([-1.0475698 , 34.297447  , -0.88388073,  4.429     ,  1.853     ,
#           1.477     ,  1.5990397 , -0.16722623,  1.922819  ], dtype=float32),
#   'num_points_in_gt': 46,
#   'difficulty': 0,
#   'group_id': 9458},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/378_car_10.bin',
#   'image_idx': 378,
#   'gt_idx': 10,
#   'box3d_lidar': array([ -1.2694429 , -72.3794    ,  -3.672171  ,   4.27      ,
#            2.218     ,   1.867     ,   1.6035427 ,  -0.15429983,
#            4.5854    ], dtype=float32),
#   'num_points_in_gt': 5,
#   'difficulty': 0,
#   'group_id': 9461},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/378_car_15.bin',
#   'image_idx': 378,
#   'gt_idx': 15,
#   'box3d_lidar': array([ -4.0884504 , -72.989006  ,  -3.5362217 ,   3.899     ,
#            1.968     ,   1.673     ,   1.657085  ,  -0.27252442,
#            2.5727184 ], dtype=float32),
#   'num_points_in_gt': 25,
#   'difficulty': 0,
#   'group_id': 9466},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/378_car_17.bin',
#   'image_idx': 378,
#   'gt_idx': 17,
#   'box3d_lidar': array([-3.2771957 , 45.519367  , -1.0432994 ,  4.461     ,  1.787     ,
#           1.534     ,  1.6697605 , -0.15857753,  0.7277504 ], dtype=float32),
#   'num_points_in_gt': 48,
#   'difficulty': 0,
#   'group_id': 9468},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/379_car_6.bin',
#   'image_idx': 379,
#   'gt_idx': 6,
#   'box3d_lidar': array([-0.8509031 , 32.25831   , -0.9211108 ,  4.429     ,  1.853     ,
#           1.477     ,  1.6054813 , -0.31264862,  1.4572693 ], dtype=float32),
#   'num_points_in_gt': 42,
#   'difficulty': 0,
#   'group_id': 9479},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/379_car_9.bin',
#   'image_idx': 379,
#   'gt_idx': 9,
#   'box3d_lidar': array([-2.1430743e+00, -7.2917473e+01, -3.7210875e+00,  4.2700000e+00,
#           2.2179999e+00,  1.8670000e+00,  1.5707144e+00, -3.4722276e-03,
#           4.5888219e+00], dtype=float32),
#   'num_points_in_gt': 5,
#   'difficulty': 0,
#   'group_id': 9482},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/379_car_14.bin',
#   'image_idx': 379,
#   'gt_idx': 14,
#   'box3d_lidar': array([ -5.0791793 , -74.379745  ,  -3.6875615 ,   3.899     ,
#            1.968     ,   1.673     ,   1.6389829 ,  -0.35713598,
#            2.8277383 ], dtype=float32),
#   'num_points_in_gt': 25,
#   'difficulty': 0,
#   'group_id': 9487},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/379_car_16.bin',
#   'image_idx': 379,
#   'gt_idx': 16,
#   'box3d_lidar': array([-2.898358  , 43.06287   , -1.0163866 ,  4.461     ,  1.787     ,
#           1.534     ,  1.6456587 , -0.1418392 ,  0.73142713], dtype=float32),
#   'num_points_in_gt': 55,
#   'difficulty': 0,
#   'group_id': 9489},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/380_car_6.bin',
#   'image_idx': 380,
#   'gt_idx': 6,
#   'box3d_lidar': array([-0.8741559 , 30.122412  , -0.9764879 ,  4.429     ,  1.853     ,
#           1.477     ,  1.6605965 , -0.39143503,  1.4742492 ], dtype=float32),
#   'num_points_in_gt': 79,
#   'difficulty': 0,
#   'group_id': 9502},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/380_car_11.bin',
#   'image_idx': 380,
#   'gt_idx': 11,
#   'box3d_lidar': array([ -2.580299  , -73.40255   ,  -3.6957114 ,   4.27      ,
#            2.218     ,   1.867     ,   1.5429263 ,   0.12403116,
#            4.5897436 ], dtype=float32),
#   'num_points_in_gt': 8,
#   'difficulty': 0,
#   'group_id': 9507},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/380_car_17.bin',
#   'image_idx': 380,
#   'gt_idx': 17,
#   'box3d_lidar': array([ -5.773433 , -75.72328  ,  -3.663441 ,   3.899    ,   1.968    ,
#            1.673    ,   1.6384656,  -0.3267204,   3.37008  ], dtype=float32),
#   'num_points_in_gt': 15,
#   'difficulty': 0,
#   'group_id': 9513},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/380_car_19.bin',
#   'image_idx': 380,
#   'gt_idx': 19,
#   'box3d_lidar': array([-2.7465804 , 40.651024  , -1.0315331 ,  4.461     ,  1.787     ,
#           1.534     ,  1.6265974 , -0.06263307,  0.7814803 ], dtype=float32),
#   'num_points_in_gt': 50,
#   'difficulty': 0,
#   'group_id': 9515},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/381_car_5.bin',
#   'image_idx': 381,
#   'gt_idx': 5,
#   'box3d_lidar': array([-0.96084714, 28.193058  , -0.9817662 ,  4.429     ,  1.853     ,
#           1.477     ,  1.7517593 , -0.40642318,  1.3014557 ], dtype=float32),
#   'num_points_in_gt': 54,
#   'difficulty': 0,
#   'group_id': 9524},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/381_car_9.bin',
#   'image_idx': 381,
#   'gt_idx': 9,
#   'box3d_lidar': array([ -2.859684  , -73.84688   ,  -3.7721095 ,   4.27      ,
#            2.218     ,   1.867     ,   1.5162795 ,   0.24660593,
#            4.5821385 ], dtype=float32),
#   'num_points_in_gt': 6,
#   'difficulty': 0,
#   'group_id': 9528},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/381_car_13.bin',
#   'image_idx': 381,
#   'gt_idx': 13,
#   'box3d_lidar': array([-6.2675252e+00, -7.6490623e+01, -3.9603291e+00,  3.8989999e+00,
#           1.9680001e+00,  1.6730000e+00,  1.6543612e+00,  1.9556401e-02,
#           3.1662464e+00], dtype=float32),
#   'num_points_in_gt': 11,
#   'difficulty': 0,
#   'group_id': 9532},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/381_car_15.bin',
#   'image_idx': 381,
#   'gt_idx': 15,
#   'box3d_lidar': array([-2.5666966e+00,  3.8323307e+01, -1.0126957e+00,  4.4610000e+00,
#           1.7869999e+00,  1.5340000e+00,  1.6275849e+00,  1.1128294e-02,
#           8.2817507e-01], dtype=float32),
#   'num_points_in_gt': 77,
#   'difficulty': 0,
#   'group_id': 9534},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/382_car_6.bin',
#   'image_idx': 382,
#   'gt_idx': 6,
#   'box3d_lidar': array([-1.1769841, 26.118391 , -1.0572355,  4.429    ,  1.853    ,
#           1.477    ,  1.7900386, -0.4106355,  0.9549758], dtype=float32),
#   'num_points_in_gt': 93,
#   'difficulty': 0,
#   'group_id': 9544},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/382_car_9.bin',
#   'image_idx': 382,
#   'gt_idx': 9,
#   'box3d_lidar': array([ -2.7424033, -74.1138   ,  -3.6717346,   4.27     ,   2.218    ,
#            1.867    ,   1.4943448,   0.4189999,   5.398273 ], dtype=float32),
#   'num_points_in_gt': 8,
#   'difficulty': 0,
#   'group_id': 9547},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/382_car_12.bin',
#   'image_idx': 382,
#   'gt_idx': 12,
#   'box3d_lidar': array([ -6.173709  , -77.83187   ,  -3.8468628 ,   3.899     ,
#            1.968     ,   1.673     ,   1.6800596 ,   0.25207776,
#            2.4351833 ], dtype=float32),
#   'num_points_in_gt': 13,
#   'difficulty': 0,
#   'group_id': 9550},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/382_car_14.bin',
#   'image_idx': 382,
#   'gt_idx': 14,
#   'box3d_lidar': array([-2.5798926e+00,  3.6181984e+01, -1.0935459e+00,  4.4610000e+00,
#           1.7869999e+00,  1.5340000e+00,  1.6332847e+00,  1.0451071e-02,
#           8.2803535e-01], dtype=float32),
#   'num_points_in_gt': 58,
#   'difficulty': 0,
#   'group_id': 9552},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/383_car_7.bin',
#   'image_idx': 383,
#   'gt_idx': 7,
#   'box3d_lidar': array([-1.5331144 , 24.063654  , -1.1405861 ,  4.429     ,  1.853     ,
#           1.477     ,  1.8329825 , -0.42991647,  0.89360064], dtype=float32),
#   'num_points_in_gt': 157,
#   'difficulty': 0,
#   'group_id': 9563},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/383_car_10.bin',
#   'image_idx': 383,
#   'gt_idx': 10,
#   'box3d_lidar': array([ -2.1704936, -73.54089  ,  -3.5989964,   4.27     ,   2.218    ,
#            1.867    ,   1.477075 ,   0.4079944,   5.892659 ], dtype=float32),
#   'num_points_in_gt': 5,
#   'difficulty': 0,
#   'group_id': 9566},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/383_car_15.bin',
#   'image_idx': 383,
#   'gt_idx': 15,
#   'box3d_lidar': array([-2.7622974e+00,  3.4061405e+01, -1.1855706e+00,  4.4610000e+00,
#           1.7869999e+00,  1.5340000e+00,  1.6436492e+00, -1.8677399e-02,
#           7.1442896e-01], dtype=float32),
#   'num_points_in_gt': 26,
#   'difficulty': 0,
#   'group_id': 9571},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/384_car_7.bin',
#   'image_idx': 384,
#   'gt_idx': 7,
#   'box3d_lidar': array([-2.0304496 , 21.77426   , -1.3503757 ,  4.429     ,  1.853     ,
#           1.477     ,  1.8814166 , -0.32126838,  0.659454  ], dtype=float32),
#   'num_points_in_gt': 321,
#   'difficulty': 0,
#   'group_id': 9582},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/384_car_10.bin',
#   'image_idx': 384,
#   'gt_idx': 10,
#   'box3d_lidar': array([ -1.3068266 , -73.23279   ,  -3.1160388 ,   4.27      ,
#            2.218     ,   1.867     ,   1.4871118 ,   0.27035525,
#            5.865052  ], dtype=float32),
#   'num_points_in_gt': 2,
#   'difficulty': 0,
#   'group_id': 9585},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/384_car_14.bin',
#   'image_idx': 384,
#   'gt_idx': 14,
#   'box3d_lidar': array([-3.1464052, 31.631777 , -1.4302804,  4.461    ,  1.787    ,
#           1.534    ,  1.6362327, -0.0445366,  0.6412579], dtype=float32),
#   'num_points_in_gt': 1,
#   'difficulty': 0,
#   'group_id': 9589},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/385_car_6.bin',
#   'image_idx': 385,
#   'gt_idx': 6,
#   'box3d_lidar': array([-2.3297615 , 19.586718  , -1.2939382 ,  4.429     ,  1.853     ,
#           1.477     ,  1.9021698 , -0.1987615 ,  0.45736527], dtype=float32),
#   'num_points_in_gt': 405,
#   'difficulty': 0,
#   'group_id': 9602},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/385_car_9.bin',
#   'image_idx': 385,
#   'gt_idx': 9,
#   'box3d_lidar': array([ -0.5802994 , -72.5548    ,  -3.4436862 ,   4.27      ,
#            2.218     ,   1.867     ,   1.4956477 ,   0.23049204,
#            6.156476  ], dtype=float32),
#   'num_points_in_gt': 2,
#   'difficulty': 0,
#   'group_id': 9605},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/385_car_13.bin',
#   'image_idx': 385,
#   'gt_idx': 13,
#   'box3d_lidar': array([-3.4542816 , 29.541618  , -1.2694945 ,  4.461     ,  1.787     ,
#           1.534     ,  1.6273153 , -0.04107028,  0.6727769 ], dtype=float32),
#   'num_points_in_gt': 7,
#   'difficulty': 0,
#   'group_id': 9609},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/386_car_5.bin',
#   'image_idx': 386,
#   'gt_idx': 5,
#   'box3d_lidar': array([-2.6944294 , 17.403734  , -1.4103085 ,  4.429     ,  1.853     ,
#           1.477     ,  1.9269145 , -0.20309496,  0.3636478 ], dtype=float32),
#   'num_points_in_gt': 494,
#   'difficulty': 0,
#   'group_id': 9620},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/386_car_8.bin',
#   'image_idx': 386,
#   'gt_idx': 8,
#   'box3d_lidar': array([  0.38727608, -71.86446   ,  -3.2316148 ,   4.27      ,
#            2.218     ,   1.867     ,   1.508175  ,   0.13930881,
#            5.5957417 ], dtype=float32),
#   'num_points_in_gt': 0,
#   'difficulty': 0,
#   'group_id': 9623},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/386_car_11.bin',
#   'image_idx': 386,
#   'gt_idx': 11,
#   'box3d_lidar': array([-3.8636317 , 27.451138  , -1.3630719 ,  4.461     ,  1.787     ,
#           1.534     ,  1.6223894 , -0.03461351,  0.61124665], dtype=float32),
#   'num_points_in_gt': 23,
#   'difficulty': 0,
#   'group_id': 9626},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/387_car_5.bin',
#   'image_idx': 387,
#   'gt_idx': 5,
#   'box3d_lidar': array([-3.0567608 , 14.644499  , -1.3957542 ,  4.429     ,  1.853     ,
#           1.477     ,  1.9664779 , -0.16649061,  0.33213845], dtype=float32),
#   'num_points_in_gt': 617,
#   'difficulty': 0,
#   'group_id': 9636},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/387_car_9.bin',
#   'image_idx': 387,
#   'gt_idx': 9,
#   'box3d_lidar': array([ 1.3297046e+00, -7.1663696e+01, -3.4759920e+00,  4.2700000e+00,
#           2.2179999e+00,  1.8670000e+00,  1.5209768e+00,  6.8970196e-02,
#           5.5993261e+00], dtype=float32),
#   'num_points_in_gt': 6,
#   'difficulty': 0,
#   'group_id': 9640},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/387_car_12.bin',
#   'image_idx': 387,
#   'gt_idx': 12,
#   'box3d_lidar': array([-4.2510056e+00,  2.4841068e+01, -1.2947015e+00,  4.4610000e+00,
#           1.7869999e+00,  1.5340000e+00,  1.6177379e+00, -9.4945496e-03,
#           1.0435203e-01], dtype=float32),
#   'num_points_in_gt': 9,
#   'difficulty': 0,
#   'group_id': 9643},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/388_car_5.bin',
#   'image_idx': 388,
#   'gt_idx': 5,
#   'box3d_lidar': array([-3.31042   , 12.466002  , -1.4819939 ,  4.429     ,  1.853     ,
#           1.477     ,  1.9617329 , -0.13682501,  0.43193632], dtype=float32),
#   'num_points_in_gt': 896,
#   'difficulty': 0,
#   'group_id': 9654},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/388_car_7.bin',
#   'image_idx': 388,
#   'gt_idx': 7,
#   'box3d_lidar': array([ 2.1848092e+00, -7.0901611e+01, -3.3461821e+00,  4.2700000e+00,
#           2.2179999e+00,  1.8670000e+00,  1.5331033e+00,  4.6295804e-04,
#           6.8415756e+00], dtype=float32),
#   'num_points_in_gt': 1,
#   'difficulty': 0,
#   'group_id': 9656},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/388_car_10.bin',
#   'image_idx': 388,
#   'gt_idx': 10,
#   'box3d_lidar': array([-4.5534325 , 22.2328    , -1.4233499 ,  4.461     ,  1.787     ,
#           1.534     ,  1.6298643 ,  0.02827288, -0.49244493], dtype=float32),
#   'num_points_in_gt': 51,
#   'difficulty': 0,
#   'group_id': 9659},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/389_car_6.bin',
#   'image_idx': 389,
#   'gt_idx': 6,
#   'box3d_lidar': array([-3.5121646 , 10.80326   , -1.5272651 ,  4.429     ,  1.853     ,
#           1.477     ,  1.9550347 , -0.15537353,  0.5958492 ], dtype=float32),
#   'num_points_in_gt': 1135,
#   'difficulty': 0,
#   'group_id': 9670},
#  {'name': 'car',
#   'path': 'nuscenes_gt_database/389_car_9.bin',
#   'image_idx': 389,
#   'gt_idx': 9,
#   'box3d_lidar': array([  2.8628922 , -69.61972   ,  -3.4158428 ,   4.27      ,
#            2.218     ,   1.867     ,   1.5432767 ,  -0.07398656,
#            7.242527  ], dtype=float32),
#   'num_points_in_gt': 4,
#   'difficulty': 0,
#   'group_id': 9673},
#  ...]
