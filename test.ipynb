# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
x = np.arange(-50, 50, 0.25)
y = np.arange(-50, 50, 0.25)
xx, yy = np.meshgrid(x,y)
zz = np.zeros_like(xx)

ax = plt.figure().add_subplot(projection='3d')
ax.plot_wireframe(xx, yy, zz, rstride=10, cstride=10)
plt.show()

# %%
import numpy as np

file_path = '/home/wsx/pointcloud_research/data/nuscenes/samples/LIDAR_TOP/n015-2018-07-18-11-50-34+0800__LIDAR_TOP__1531886224949600.pcd.bin'

with open(file_path, "rb") as f:
    number = f.read(4)
    while number != b"":
        print(np.frombuffer(number, dtype=np.float32))
        number = f.read(4)
# Out:
# [-2.8323648]
# [-0.38808885]
# [-1.6815873]
# [21.]
# [0.]
# [-2.9754634]
# [-0.3862887]
# [-1.6736307]
# [31.]
# [1.]
# [-3.1087983]
# [-0.38499188]
# [-1.6547819]
# [35.]
# [2.]
# [-3.2484198]
# [-0.3830654]
# [-1.6327404]
# [34.]
# [3.]
# [-3.4679937]
# [-0.38046598]
# [-1.6432457]
# [33.]
# [4.]
# [-3.6933494]
# [-0.3783332]
# [-1.6460161]
# [32.]
# [5.]
# [-3.887301]
# [-0.3757051]
# [-1.6253052]
# [35.]
# [6.]
# [-4.1626472]
# [-0.3723012]
# [-1.6269696]
# [39.]
# [7.]
# [-4.471777]
# [-0.36919957]
# [-1.6289797]
# [34.]
# [8.]
# [-4.7944736]
# [-0.36504325]
# [-1.6212974]
# [63.]
# [9.]
# [-4.890155]
# [-0.36260718]
# [-1.5271782]
# [47.]
# [10.]
# [-4.87992]
# [-0.3619038]
# [-1.4006047]
# [27.]
# [11.]
# [-5.222578]
# [-0.35715604]
# [-1.36837]
# [14.]
# [12.]
# [-5.698741]
# [-0.35195893]
# [-1.3512661]
# [30.]
# [13.]
# [-6.2743216]
# [-0.34457228]
# [-1.3344047]
# [47.]
# [14.]
# [-6.946177]
# [-0.33588332]
# [-1.3092219]
# [23.]
# [15.]
# [-7.800034]
# [-0.3602604]
# ...

# %%
s = 'n008-2018-09-18-14-35-12-0400__LIDAR_TOP__1537296188900729.pcd.bin'

# %%
tmp = s.split("__")

# %%
tmp
# Out:
# ['n008-2018-09-18-14-35-12-0400', 'LIDAR_TOP', '1537296188900729.pcd.bin']

# %%
"_".join(tmp[::2])
# Out:
# 'n008-2018-09-18-14-35-12-0400_1537296188900729.pcd.bin'

# %%
tmp
# Out:
# ['n008-2018-09-18-14-35-12-0400', 'LIDAR_TOP', '1537296188900729.pcd.bin']

# %%
import os

# %%
dp = "/usr/include/pcl-1.10/pcl/"

# %%
f = os.listdir(dp)

# %%
tmp = []
for i in f:
    if len(i.split(".")) == 1:
        tmp.append(i)

# %%
for i in sorted(tmp):
    p = os.path.join(dp, i)
    print(str(p))
# Out:
# /usr/include/pcl-1.10/pcl/2d
# /usr/include/pcl-1.10/pcl/apps
# /usr/include/pcl-1.10/pcl/common
# /usr/include/pcl-1.10/pcl/compression
# /usr/include/pcl-1.10/pcl/console
# /usr/include/pcl-1.10/pcl/features
# /usr/include/pcl-1.10/pcl/filters
# /usr/include/pcl-1.10/pcl/geometry
# /usr/include/pcl-1.10/pcl/impl
# /usr/include/pcl-1.10/pcl/in_hand_scanner
# /usr/include/pcl-1.10/pcl/io
# /usr/include/pcl-1.10/pcl/kdtree
# /usr/include/pcl-1.10/pcl/keypoints
# /usr/include/pcl-1.10/pcl/ml
# /usr/include/pcl-1.10/pcl/octree
# /usr/include/pcl-1.10/pcl/outofcore
# /usr/include/pcl-1.10/pcl/people
# /usr/include/pcl-1.10/pcl/range_image
# /usr/include/pcl-1.10/pcl/recognition
# /usr/include/pcl-1.10/pcl/registration
# /usr/include/pcl-1.10/pcl/sample_consensus
# /usr/include/pcl-1.10/pcl/search
# /usr/include/pcl-1.10/pcl/segmentation
# /usr/include/pcl-1.10/pcl/stereo
# /usr/include/pcl-1.10/pcl/surface
# /usr/include/pcl-1.10/pcl/tracking
# /usr/include/pcl-1.10/pcl/visualization
